# %% [markdown]
# # Ejercicio para aplicar en orange
# 1. Se crea un data set  de entrenamiento para realizar la regresión polinomial. </p>
# - Este data set corresponde al 80% de los datos. </p>
# 2. Se crea un data set de de test para realizar la regresión polinomial. </p>
# - Este data set corresponde al 20% de los datos </p>

# %% [markdown]
# # Dividir datos 80% guardar como entrenamiento

# %%
import pandas as pd

# %%
#leer el data set 
df = pd.read_csv('automovilesEDA-curso.csv')
df
# Out:
#      gradoRiesgo  perdidasNormalizadas        marca aspiracion nroPuertas  \
# 0              3                   122  alfa-romero        std        two
# 1              3                   122  alfa-romero        std        two
# 2              1                   122  alfa-romero        std        two
# 3              2                   164         audi        std       four
# 4              2                   164         audi        std       four
# ..           ...                   ...          ...        ...        ...
# 196           -1                    95        volvo        std       four
# 197           -1                    95        volvo      turbo       four
# 198           -1                    95        volvo        std       four
# 199           -1                    95        volvo      turbo       four
# 200           -1                    95        volvo      turbo       four
#
#       tipoCabina tipoTraccion ubicacionMotor  distanciaRuedas     largo  ...  \
# ...

# %%
#tomar los valores de filas y columnas
num = df.shape
#filas y columnas contadas
filas = num[0]
#columnas 
columns = num[1]
#calcular 80%
calcular = filas*0.8
#80% del data set
calcular

# %%
#dividir el conjunto 
#esta es la primera parte que equivale al 80% del data set
data_entrenamiento = df.iloc[0:160]

# %% [markdown]
# # Dividir en 20% guardar como evaluacion

# %%
#esta es la segunda parte que equivale al 20% del data set
data_evaluacion = df.iloc[160:]
data_evaluacion

# %% [markdown]
# # Guardar las tablas del 80% y 20% como csv
# - Importar las tablas o csv en orange. </p>
# - Realizar las acciones correspondientes. </p>

# %%
# guardar en csv el 80%
data_entrenamiento.to_csv("Data_set_entrenamiento.csv", index=False)
# guardar en csv el 20%
data_evaluacion.to_csv("Data_set_evaluacion.csv", index=False)
